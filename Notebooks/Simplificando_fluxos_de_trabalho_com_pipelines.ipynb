# %%
from IPython.display import Image

# %% [markdown]
# # Simplificando fluxos de trabalho com a classe `pipeline` fo `scikit-learn`
#
# ## Carregando o conjunto de dados sobre câncer de mama
# - 569 padrões,
# - Classes: `M` (para tumor malígno) e `B` (para tumor benigno),
# - 30 features extraídas de imagens de células

# %%
import pandas as pd

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', header=None)

# %%
df.head()
# Out:
#          0  1      2      3       4   ...      27      28      29      30       31
# 0    842302  M  17.99  10.38  122.80  ...  0.6656  0.7119  0.2654  0.4601  0.11890
# 1    842517  M  20.57  17.77  132.90  ...  0.1866  0.2416  0.1860  0.2750  0.08902
# 2  84300903  M  19.69  21.25  130.00  ...  0.4245  0.4504  0.2430  0.3613  0.08758
# 3  84348301  M  11.42  20.38   77.58  ...  0.8663  0.6869  0.2575  0.6638  0.17300
# 4  84358402  M  20.29  14.34  135.10  ...  0.2050  0.4000  0.1625  0.2364  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# Mapeamento de classes
# - `M` (Malígno) -> `1`
# - `B` (Benigno) -> `0`

# %%
from sklearn.preprocessing import LabelEncoder

x = df.loc[:, 2:].values
y = df.loc[:, 1].values

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
le.transform(['M', 'B'])
# Out:
# array([1, 0])

# %% [markdown]
# Separando treino e teste

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, stratify=y, random_state=1)

# %%
# Normalizar dados 
from sklearn.preprocessing import StandardScaler
# Reduzir a dimensionalidade
from sklearn.decomposition import PCA
# Regressão Logística
from sklearn.linear_model import LogisticRegression
# Pipeline
from sklearn.pipeline import make_pipeline

pipe_lr = make_pipeline(StandardScaler(), 
                        PCA(n_components=2),
                        LogisticRegression(random_state=1, solver='lbfgs'))

pipe_lr.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('pca',
#                  PCA(copy=True, iterated_power='auto', n_components=2,
#                      random_state=None, svd_solver='auto', tol=0.0,
#                      whiten=False)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=1,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# # Combinando transformações e estimadores em um único pipeline
#
# **Pipeline**
# 1. Transformar: normalização,
# 2. Transformar: redução de dimensionalidade
# 3. Estimar: regressão logística

# %%
y_pred = pipe_lr.predict(X_test)
print('Teste de acurácia: %.3f' % pipe_lr.score(X_test, y_test))
# Out:
# Teste de acurácia: 0.956

# %%
Image(filename='/content/pipeline.png', width=500)
